# %%
print ('ciao')
# Out:
# ciao

# %%
import numpy as f
numeri_primi = []
for n in range(0, 11):
    if (n>1):
        x=0
        for i in range(2, n):
            if n%i==0:
                x=1
        if x==0:
            numeri_primi.append(n)
numeri_primi
# Out:
# [2, 3, 5, 7]

# %%
len(numeri_primi)
# Out:
# 4

# %%
vettore = f.array(numeri_primi)
vettore.size
# Out:
# 4
