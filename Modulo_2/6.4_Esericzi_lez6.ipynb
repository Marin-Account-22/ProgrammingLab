# %% [markdown]
# # 4. Rispondere alle domande
# Trasforma le seguenti richiesti in formule per estrarre infromazioni dal dataframe
# - Mostrami le vendite maggiori di 10
#
# - Mostrami i dati del 2018
#
# - Mostrami le vendite maggiori di 13 e l'anno è il 2018
#
# - Mostrami tutto TRANNE i casi in cui le vendite sono maggiori di 13 e l'anno è il 2018
#
# - Mostrami i dati dove le vendite divise per 3 sono maggiori di 3
#
# - Mostrami i dipendenti i cui nomi sono alfabeticamente dopo la J

# %%
import pandas as pd
sales=pd.DataFrame(
    data={
        "dipendente": [
            "Katrina",
            "Guanyu",
            "Jan",
            "Roman",
            "Jacqueline",
            "Paola",
            "Esperanza",
            "Alaina",
            "Egweyn"
        ],
        "sales": [14, 17, 6, 12, 8, 3, 7, 15, 5],
        "year": [2018, 2019, 2020, 2018, 2020, 2019, 2019, 2020, 2020]
    }
)
print(sales.query("sales>10"))
print("\n")
print(sales.query("year==2018"))
print("\n")
print(sales.query("sales>13 and year==2018"))
print("\n")
print(sales.query("not (sales>13 and year==2018)"))
print("\n")
print(sales.query("(sales/3)>3"))
print("\n")
print(sales.query("dipendente > \"J\""))
# Out:
#   dipendente  sales  year
# 0    Katrina     14  2018
# 1     Guanyu     17  2019
# 3      Roman     12  2018
# 7     Alaina     15  2020
#
#
#   dipendente  sales  year
# 0    Katrina     14  2018
# 3      Roman     12  2018
#
#
#   dipendente  sales  year
# 0    Katrina     14  2018
#
#
#    dipendente  sales  year
# 1      Guanyu     17  2019
# 2         Jan      6  2020
# 3       Roman     12  2018
# 4  Jacqueline      8  2020
# 5       Paola      3  2019
# 6   Esperanza      7  2019
# 7      Alaina     15  2020
# 8      Egweyn      5  2020
#
#
#   dipendente  sales  year
# 0    Katrina     14  2018
# 1     Guanyu     17  2019
# 3      Roman     12  2018
# 7     Alaina     15  2020
#
#
#    dipendente  sales  year
# 0     Katrina     14  2018
# 2         Jan      6  2020
# 3       Roman     12  2018
# 4  Jacqueline      8  2020
# 5       Paola      3  2019

# %% [markdown]
# # 5. Analisi di un dataset di video giochi
# 1. Quanti videogiochi sono stati pubblicati
# 2. Quali sono i generi più popolari? Mostralo con un bar plot
# 3. Plotta l'evoluzione del numero di giochi pubblicati nel tempo
# 4. Prova a riprodurre questo plot
#
# ![image.png](attachment:image.png)

# %%
# Import dei pacchetti
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Caricamento del dataset
url = 'https://zenodo.org/record/5898311/files/vgsales.csv'
df = pd.read_csv(url)

print(len(df))
print("\n")
plt.figure(figsize=(10, 6))
df["Genre"].value_counts().plot(kind="bar", color="lightgreen")
plt.title("Generi più popolari")
plt.xlabel("Genere")
plt.ylabel("Numero di giochi")
plt.figure(figsize=(10, 6))
df.groupby("Year")["Name"].count().plot(kind="line", marker="o")
plt.title("Evoluzione del numero di giochi pubblicati nel tempo")
plt.xlabel("Anno")
plt.ylabel("Numero di giochi")
plt.grid(True)
colonne_vendite=["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]
top_generi=["Action", "Misc", "Role-Playing", "Shooter", "Sports"]
df_filtrato=df[df["Genre"].isin(top_generi)]
dati_plot=df_filtrato.groupby("Genre")[colonne_vendite].sum()
dati_plot.plot(kind="bar", stacked=True, figsize=(10, 6))
plt.title("Vendite per regione per genere")
plt.xlabel("Genre")
plt.ylabel("Milioni di unità")
plt.legend(title="Regioni")
plt.show()
# Out:
# 16598
